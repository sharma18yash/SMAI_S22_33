# %% [markdown]
# #Import Modules

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, Flatten

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.optimizers.schedules import ExponentialDecay

from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import LearningRateScheduler

# %% [markdown]
# #Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Import train400 Dataset

# %%
# images = []
# for i in range(9):
#   image = tf.keras.preprocessing.image.load_img("/content/drive/MyDrive/train400/00{}.png".format(i+1))
#   input_arr = tf.keras.preprocessing.image.img_to_array(image)
#   img = np.divide(input_arr, 255.0)
#   images.append(img)

# for i in range(10, 99):
#   image = tf.keras.preprocessing.image.load_img("/content/drive/MyDrive/train400/0{}.png".format(i))
#   input_arr = tf.keras.preprocessing.image.img_to_array(image)
#   img = np.divide(input_arr, 255.0)
#   images.append(img)

# for i in range(100, 400):
#   image = tf.keras.preprocessing.image.load_img("/content/drive/MyDrive/train400/{}.png".format(i))
#   input_arr = tf.keras.preprocessing.image.img_to_array(image)
#   img = np.divide(input_arr, 255.0)
#   images.append(img)

# %%
# images = np.array(images)
# print(images.shape)

# %%
base_url = "/content/drive/MyDrive/datas/"
folders = ["train400", "LIVE1", "LIVE1_q10", "LIVE1_q20", "LIVE1_q30", "LIVE1_q40", "BSD68"]

# %%
import subprocess
images = []
for folder in folders:
  output = subprocess.check_output("ls " + base_url + folder, shell=True)
  print(type(output))
  files_list = output.decode('utf-8').split('\n')
  files_list.pop()

  for image in files_list:
    image_real = tf.keras.preprocessing.image.load_img(base_url + folder + "/" +image)
    image_real = image_real.resize((300,300))
    input_arr = tf.keras.preprocessing.image.img_to_array(image_real)
    #  input_arr = input_arr.reshape((180,180,3))
    img = np.divide(input_arr, 255.0)
    images.append(img)
# Out:
# <class 'bytes'>
# <class 'bytes'>
# <class 'bytes'>
# <class 'bytes'>
# <class 'bytes'>
# <class 'bytes'>
# <class 'bytes'>

# %%
images = np.array(images)
print(images.shape)
# Out:
# (613, 300, 300, 3)

# %% [markdown]
# #ADD NOISE TO IMAGE

# %%
tf.convert_to_tensor(img, dtype=None, dtype_hint=None, name=None)

import numpy as np
import os
import cv2
def noisy(image):
    row,col,ch= image.shape
    mean = 0
    var = 0.1
    sigma = var**0.5
    gauss = np.random.normal(mean,sigma,(row,col,ch))
    gauss = gauss.reshape(row,col,ch)
    noisy = image + gauss
    return noisy

# %%
import numpy
noise_factor = 0.2
noisy_images = images + noise_factor * numpy.random.normal(loc=0.0, scale=1.0, size=images.shape)
# x_test_noisy = X_test + noise_factor * numpy.random.normal(loc=0.0, scale=1.0, size=X_test.shape)
x_train_noisy = numpy.clip(noisy_images, 0., 1.)
# x_test_noisy = numpy.clip(x_test_noisy, 0., 1.)

# %%
# image_noisy = []
# for img in images:
#   image_noisy.append(noisy(img))

# %%
# image_noisy = np.array(image_noisy)
# image_noisy.shape
# plt.imshow(images[0].reshape(300,300,3))
# print(type(images), type(image_noisy))
# print(images.shape, image_noisy.shape)
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (613, 300, 300, 3) (613, 300, 300, 3)

# %%
plt.imshow(noisy_images[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #CREATING TRAINING AND VALIDATION DATASET

# %%
train_images = images[0:500]
train_images_noisy = noisy_images[0:500]

val_images = images[500:613]
val_images_noisy = noisy_images[500:613]

print(train_images.shape, train_images_noisy.shape, val_images.shape, val_images_noisy.shape)
# Out:
# (500, 300, 300, 3) (500, 300, 300, 3) (113, 300, 300, 3) (113, 300, 300, 3)

# %% [markdown]
# #MODEL ARCHITECTURE

# %%
input = layers.Input(shape=(300, 300, 3))

# %%
# Encoder
def feature_extraction(input):
  # upper model
  x1 = layers.Conv2D(16, (3, 3), activation="relu", padding="same")(input)
  x2 = layers.Conv2D(16, (3, 3), activation="relu", padding="same",dilation_rate=(2,2))(x1)

  # lower model
  y1 = layers.Conv2D(16, (3, 3), activation="relu", padding="same",dilation_rate=(2,2))(input)
  y2 = layers.Conv2D(16, (3, 3), activation="relu", padding="same")(y1)

  # concat upper and lower model in feature extraction
  concatenated = tf.keras.layers.Concatenate(axis=-1)([x1, x2, y1, y2])

  return concatenated

# %%
# Start of feature integration
def feature_integration(concatenated):
  conc_conv1 = layers.Conv2D(32, (1, 1), activation="sigmoid", padding="same")(concatenated)

  x3 = layers.Conv2D(16, (3, 3), activation="relu", padding="same")(conc_conv1)
  x4 = layers.Conv2D(16, (3, 3), activation="relu", padding="same",dilation_rate=(2,2))(x3)

  # x4  = layers.Dropout(0.2)(x4)

  y3 = layers.Conv2D(16, (3, 3), activation="relu", padding="same",dilation_rate=(2,2))(conc_conv1)
  y4 = layers.Conv2D(16, (3, 3), activation="relu", padding="same")(y3)

  # y4  = layers.Dropout(0.2)(y4)

  concatenated2 = tf.keras.layers.Concatenate(axis=-1)([x3, x4, y3, y4])

  print(concatenated2.shape)

  conc_conv2 = layers.Conv2D(16, (1, 1), activation="relu", padding="same")(concatenated2)

  concatenated3 = tf.keras.layers.Concatenate(axis=-1)([conc_conv1, conc_conv2])

  print(concatenated3.shape)

  return concatenated3

# %%
# reconstruction
def reconstruction(concatenated3):
  x = layers.Conv2DTranspose(16, (3, 3), activation="relu", padding="same")(concatenated3)
  x = layers.Conv2DTranspose(16, (3, 3), activation="relu",  padding="same", dilation_rate=(2,2))(x)
  out = layers.Conv2D(3, (1, 1), activation="sigmoid", padding="same")(x)
  return out

# %%
#making the ddfn model
model = feature_extraction(input)
for _ in range(1):
  model = feature_integration(model)
out_1 = reconstruction(model)

model = feature_extraction(input)
for _ in range(3):
  model = feature_integration(model)
out_3 = reconstruction(model)

model = feature_extraction(input)
for _ in range(5):
  model = feature_integration(model)
out_5 = reconstruction(model)

model = feature_extraction(input)
for _ in range(7):
  model = feature_integration(model)
out_7 = reconstruction(model)
# Out:
# (None, 300, 300, 64)
# (None, 300, 300, 48)
# (None, 300, 300, 64)
# (None, 300, 300, 48)
# (None, 300, 300, 64)
# (None, 300, 300, 48)
# (None, 300, 300, 64)
# (None, 300, 300, 48)

# %%
initial_learning_rate = 0.001
lr_schedule = ExponentialDecay(
    initial_learning_rate,
    decay_steps=100000,
    decay_rate=0.96,
    staircase=True)

# %%
# running the model
import pickle
autoencoder1 = Model(input, out_1)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)
autoencoder1.compile(optimizer=opt, loss="binary_crossentropy")
autoencoder1.summary()

# early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
history1 = autoencoder1.fit(x=train_images_noisy,y=train_images,epochs=15,batch_size=16,validation_data=(val_images_noisy, val_images))

filename = '1_layer.sav'
pickle.dump(autoencoder1, open(filename, 'wb'))
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 300, 300, 3  0           []
#                                 )]
#
#  conv2d_232 (Conv2D)            (None, 300, 300, 16  448         ['input_2[0][0]']
#                                 )
#
#  conv2d_234 (Conv2D)            (None, 300, 300, 16  448         ['input_2[0][0]']
#                                 )
#
#  conv2d_233 (Conv2D)            (None, 300, 300, 16  2320        ['conv2d_232[0][0]']
#                                 )
#
#  conv2d_235 (Conv2D)            (None, 300, 300, 16  2320        ['conv2d_234[0][0]']
#                                 )
#
#  concatenate_72 (Concatenate)   (None, 300, 300, 64  0           ['conv2d_232[0][0]',
#                                 )                                 'conv2d_233[0][0]',
#                                                                   'conv2d_234[0][0]',
#                                                                   'conv2d_235[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 300, 300, 32  2080        ['concatenate_72[0][0]']
#                                 )
#
#  conv2d_237 (Conv2D)            (None, 300, 300, 16  4624        ['conv2d_236[0][0]']
#                                 )
#
#  conv2d_239 (Conv2D)            (None, 300, 300, 16  4624        ['conv2d_236[0][0]']
#                                 )
#
#  conv2d_238 (Conv2D)            (None, 300, 300, 16  2320        ['conv2d_237[0][0]']
#                                 )
#
#  conv2d_240 (Conv2D)            (None, 300, 300, 16  2320        ['conv2d_239[0][0]']
#                                 )
#
#  concatenate_73 (Concatenate)   (None, 300, 300, 64  0           ['conv2d_237[0][0]',
#                                 )                                 'conv2d_238[0][0]',
#                                                                   'conv2d_239[0][0]',
#                                                                   'conv2d_240[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 300, 300, 16  1040        ['concatenate_73[0][0]']
#                                 )
#
#  concatenate_74 (Concatenate)   (None, 300, 300, 48  0           ['conv2d_236[0][0]',
#                                 )                                 'conv2d_241[0][0]']
#
#  conv2d_transpose_16 (Conv2DTra  (None, 300, 300, 16  6928       ['concatenate_74[0][0]']
#  nspose)                        )
#
#  conv2d_transpose_17 (Conv2DTra  (None, 300, 300, 16  2320       ['conv2d_transpose_16[0][0]']
#  nspose)                        )
#
#  conv2d_242 (Conv2D)            (None, 300, 300, 3)  51          ['conv2d_transpose_17[0][0]']
#
# ==================================================================================================
# Total params: 31,843
# Trainable params: 31,843
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/15
# 32/32 [==============================] - 28s 822ms/step - loss: 0.6801 - val_loss: 0.6520
# Epoch 2/15
# 32/32 [==============================] - 25s 796ms/step - loss: 0.6126 - val_loss: 0.5961
# Epoch 3/15
# 32/32 [==============================] - ETA: 0s - loss: 0.5877
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-898e76796008> in <module>()
#       7
#       8 # early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
# ----> 9 history1 = autoencoder1.fit(x=train_images_noisy,y=train_images,epochs=15,batch_size=16,validation_data=(val_images_noisy, val_images))
#      10
#      11 filename = '1_layer.sav'
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1429               use_multiprocessing=use_multiprocessing,
#    1430               return_dict=True,
# -> 1431               _use_cached_eval_dataset=True)
#    1432           val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1433           epoch_logs.update(val_logs)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1714             with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1715               callbacks.on_test_batch_begin(step)
# -> 1716               tmp_logs = self.test_function(iterator)
#    1717               if data_handler.should_sync:
#    1718                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
autoencoder3 = Model(input, out_3)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)
autoencoder3.compile(optimizer=opt, loss="binary_crossentropy", metrics = ['accuracy'])
autoencoder3.summary()

# early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
history3 = autoencoder3.fit(x=train_images_noisy,y=train_images,epochs=100,batch_size=16,validation_data=(val_images_noisy, val_images))

filename = '3_layer.sav'
pickle.dump(autoencoder3, open(filename, 'wb'))
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 300, 300, 3  0           []
#                                 )]
#
#  conv2d_11 (Conv2D)             (None, 300, 300, 16  448         ['input_1[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 300, 300, 16  448         ['input_1[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_11[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_13[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 300, 300, 64  0           ['conv2d_11[0][0]',
#                                 )                                 'conv2d_12[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 300, 300, 32  2080        ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_15[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_15[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_18[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 300, 300, 64  0           ['conv2d_16[0][0]',
#                                 )                                 'conv2d_17[0][0]',
#                                                                   'conv2d_18[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 300, 300, 16  1040        ['concatenate_4[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 300, 300, 48  0           ['conv2d_15[0][0]',
#                                 )                                 'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 300, 300, 32  1568        ['concatenate_5[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_21[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_21[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_22[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_24[0][0]']
#                                 )
#
#  concatenate_6 (Concatenate)    (None, 300, 300, 64  0           ['conv2d_22[0][0]',
#                                 )                                 'conv2d_23[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 300, 300, 16  1040        ['concatenate_6[0][0]']
#                                 )
#
#  concatenate_7 (Concatenate)    (None, 300, 300, 48  0           ['conv2d_21[0][0]',
#                                 )                                 'conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 300, 300, 32  1568        ['concatenate_7[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_27[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_27[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_28[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_30[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 300, 300, 64  0           ['conv2d_28[0][0]',
#                                 )                                 'conv2d_29[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 300, 300, 16  1040        ['concatenate_8[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 300, 300, 48  0           ['conv2d_27[0][0]',
#                                 )                                 'conv2d_32[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 300, 300, 16  6928       ['concatenate_9[0][0]']
#  spose)                         )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 300, 300, 16  2320       ['conv2d_transpose_2[0][0]']
#  spose)                         )
#
#  conv2d_33 (Conv2D)             (None, 300, 300, 3)  51          ['conv2d_transpose_3[0][0]']
#
# ==================================================================================================
# Total params: 64,835
# Trainable params: 64,835
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 32/32 [==============================] - 26s 765ms/step - loss: 0.6866 - accuracy: 0.4366 - val_loss: 0.6862 - val_accuracy: 0.0033
# Epoch 2/100
# 32/32 [==============================] - 24s 756ms/step - loss: 0.6858 - accuracy: 0.4369 - val_loss: 0.6822 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 32/32 [==============================] - 24s 765ms/step - loss: 0.6573 - accuracy: 0.3991 - val_loss: 0.6349 - val_accuracy: 0.0876
# Epoch 4/100
# 32/32 [==============================] - 25s 769ms/step - loss: 0.6231 - accuracy: 0.1761 - val_loss: 0.6255 - val_accuracy: 0.0856
# Epoch 5/100
# 32/32 [==============================] - 25s 775ms/step - loss: 0.6180 - accuracy: 0.2404 - val_loss: 0.6214 - val_accuracy: 0.2881
# Epoch 6/100
# 32/32 [==============================] - 25s 789ms/step - loss: 0.6137 - accuracy: 0.2535 - val_loss: 0.6169 - val_accuracy: 0.1808
# Epoch 7/100
# 32/32 [==============================] - 25s 792ms/step - loss: 0.5985 - accuracy: 0.2627 - val_loss: 0.5940 - val_accuracy: 0.0983
# Epoch 8/100
# 32/32 [==============================] - 25s 787ms/step - loss: 0.5863 - accuracy: 0.2590 - val_loss: 0.5897 - val_accuracy: 0.3427
# Epoch 9/100
# 32/32 [==============================] - 25s 791ms/step - loss: 0.5846 - accuracy: 0.3140 - val_loss: 0.5885 - val_accuracy: 0.2912
# Epoch 10/100
# 32/32 [==============================] - 25s 791ms/step - loss: 0.5842 - accuracy: 0.3462 - val_loss: 0.5883 - val_accuracy: 0.3422
# Epoch 11/100
# 32/32 [==============================] - 25s 794ms/step - loss: 0.5836 - accuracy: 0.3711 - val_loss: 0.5876 - val_accuracy: 0.4805
# Epoch 12/100
# 32/32 [==============================] - 25s 795ms/step - loss: 0.5830 - accuracy: 0.3783 - val_loss: 0.5886 - val_accuracy: 0.5068
# Epoch 13/100
# 32/32 [==============================] - 25s 793ms/step - loss: 0.5831 - accuracy: 0.3769 - val_loss: 0.5874 - val_accuracy: 0.3563
# Epoch 14/100
# 32/32 [==============================] - 25s 792ms/step - loss: 0.5826 - accuracy: 0.3721 - val_loss: 0.5867 - val_accuracy: 0.3443
# Epoch 15/100
# 32/32 [==============================] - 25s 792ms/step - loss: 0.5824 - accuracy: 0.3760 - val_loss: 0.5865 - val_accuracy: 0.3201
# Epoch 16/100
# 32/32 [==============================] - 25s 791ms/step - loss: 0.5822 - accuracy: 0.3716 - val_loss: 0.5869 - val_accuracy: 0.5168
# Epoch 17/100
# 32/32 [==============================] - 25s 793ms/step - loss: 0.5824 - accuracy: 0.3780 - val_loss: 0.5866 - val_accuracy: 0.4663
# Epoch 18/100
# 32/32 [==============================] - 25s 793ms/step - loss: 0.5826 - accuracy: 0.3890 - val_loss: 0.5892 - val_accuracy: 0.0844
# Epoch 19/100
# 32/32 [==============================] - 25s 793ms/step - loss: 0.5827 - accuracy: 0.3770 - val_loss: 0.5864 - val_accuracy: 0.4857

# %%
autoencoder5 = Model(input, out_5)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)
autoencoder5.compile(optimizer=opt, loss="binary_crossentropy", metrics = ['accuracy'])
autoencoder5.summary()

# early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
history5 = autoencoder5.fit(x=train_images_noisy,y=train_images,epochs=100,batch_size=16,validation_data=(val_images_noisy, val_images))
filename = '5_layer.sav'
pickle.dump(autoencoder5, open(filename, 'wb'))
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 300, 300, 3  0           []
#                                 )]
#
#  conv2d_34 (Conv2D)             (None, 300, 300, 16  448         ['input_1[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 300, 300, 16  448         ['input_1[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_34[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_36[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 300, 300, 64  0           ['conv2d_34[0][0]',
#                                 )                                 'conv2d_35[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 300, 300, 32  2080        ['concatenate_10[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_38[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_38[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_39[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_41[0][0]']
#                                 )
#
#  concatenate_11 (Concatenate)   (None, 300, 300, 64  0           ['conv2d_39[0][0]',
#                                 )                                 'conv2d_40[0][0]',
#                                                                   'conv2d_41[0][0]',
#                                                                   'conv2d_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 300, 300, 16  1040        ['concatenate_11[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 300, 300, 48  0           ['conv2d_38[0][0]',
#                                 )                                 'conv2d_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 300, 300, 32  1568        ['concatenate_12[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_44[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_44[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_45[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_47[0][0]']
#                                 )
#
#  concatenate_13 (Concatenate)   (None, 300, 300, 64  0           ['conv2d_45[0][0]',
#                                 )                                 'conv2d_46[0][0]',
#                                                                   'conv2d_47[0][0]',
#                                                                   'conv2d_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 300, 300, 16  1040        ['concatenate_13[0][0]']
#                                 )
#
#  concatenate_14 (Concatenate)   (None, 300, 300, 48  0           ['conv2d_44[0][0]',
#                                 )                                 'conv2d_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 300, 300, 32  1568        ['concatenate_14[0][0]']
#                                 )
#
#  conv2d_51 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_50[0][0]']
#                                 )
#
#  conv2d_53 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_50[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_51[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_53[0][0]']
#                                 )
#
#  concatenate_15 (Concatenate)   (None, 300, 300, 64  0           ['conv2d_51[0][0]',
#                                 )                                 'conv2d_52[0][0]',
#                                                                   'conv2d_53[0][0]',
#                                                                   'conv2d_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 300, 300, 16  1040        ['concatenate_15[0][0]']
#                                 )
#
#  concatenate_16 (Concatenate)   (None, 300, 300, 48  0           ['conv2d_50[0][0]',
#                                 )                                 'conv2d_55[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 300, 300, 32  1568        ['concatenate_16[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_56[0][0]']
#                                 )
#
#  conv2d_59 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_56[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_57[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_59[0][0]']
#                                 )
#
#  concatenate_17 (Concatenate)   (None, 300, 300, 64  0           ['conv2d_57[0][0]',
#                                 )                                 'conv2d_58[0][0]',
#                                                                   'conv2d_59[0][0]',
#                                                                   'conv2d_60[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 300, 300, 16  1040        ['concatenate_17[0][0]']
#                                 )
#
#  concatenate_18 (Concatenate)   (None, 300, 300, 48  0           ['conv2d_56[0][0]',
#                                 )                                 'conv2d_61[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 300, 300, 32  1568        ['concatenate_18[0][0]']
#                                 )
#
#  conv2d_63 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_62[0][0]']
#                                 )
#
#  conv2d_65 (Conv2D)             (None, 300, 300, 16  4624        ['conv2d_62[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_63[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 300, 300, 16  2320        ['conv2d_65[0][0]']
#                                 )
#
#  concatenate_19 (Concatenate)   (None, 300, 300, 64  0           ['conv2d_63[0][0]',
#                                 )                                 'conv2d_64[0][0]',
#                                                                   'conv2d_65[0][0]',
#                                                                   'conv2d_66[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 300, 300, 16  1040        ['concatenate_19[0][0]']
#                                 )
#
#  concatenate_20 (Concatenate)   (None, 300, 300, 48  0           ['conv2d_62[0][0]',
#                                 )                                 'conv2d_67[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 300, 300, 16  6928       ['concatenate_20[0][0]']
#  spose)                         )
#
#  conv2d_transpose_5 (Conv2DTran  (None, 300, 300, 16  2320       ['conv2d_transpose_4[0][0]']
#  spose)                         )
#
#  conv2d_68 (Conv2D)             (None, 300, 300, 3)  51          ['conv2d_transpose_5[0][0]']
#
# ==================================================================================================
# Total params: 97,827
# Trainable params: 97,827
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.6868 - accuracy: 0.3271 - val_loss: 0.6861 - val_accuracy: 0.0100
# Epoch 2/100
# 32/32 [==============================] - 36s 1s/step - loss: 0.6862 - accuracy: 0.1776 - val_loss: 0.6859 - val_accuracy: 0.9900
# Epoch 3/100
# 32/32 [==============================] - 36s 1s/step - loss: 0.6858 - accuracy: 0.4051 - val_loss: 0.6848 - val_accuracy: 0.0110
# Epoch 4/100
# 32/32 [==============================] - 39s 1s/step - loss: 0.6747 - accuracy: 0.4821 - val_loss: 0.6427 - val_accuracy: 0.1251
# Epoch 5/100
# 32/32 [==============================] - 37s 1s/step - loss: 0.6241 - accuracy: 0.6024 - val_loss: 0.6005 - val_accuracy: 0.4856
# Epoch 6/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5892 - accuracy: 0.2668 - val_loss: 0.5902 - val_accuracy: 0.0685
# Epoch 7/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5861 - accuracy: 0.3353 - val_loss: 0.5891 - val_accuracy: 0.1907
# Epoch 8/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5847 - accuracy: 0.2566 - val_loss: 0.5885 - val_accuracy: 0.2010
# Epoch 9/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5841 - accuracy: 0.2660 - val_loss: 0.5881 - val_accuracy: 0.2977
# Epoch 10/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5841 - accuracy: 0.2550 - val_loss: 0.5906 - val_accuracy: 0.2474
# Epoch 11/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5847 - accuracy: 0.2500 - val_loss: 0.5881 - val_accuracy: 0.2467
# Epoch 12/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5834 - accuracy: 0.2827 - val_loss: 0.5872 - val_accuracy: 0.2759
# Epoch 13/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5829 - accuracy: 0.2883 - val_loss: 0.5870 - val_accuracy: 0.2985
# Epoch 14/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5827 - accuracy: 0.3000 - val_loss: 0.5869 - val_accuracy: 0.2783
# Epoch 15/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5825 - accuracy: 0.3133 - val_loss: 0.5868 - val_accuracy: 0.2752
# Epoch 16/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5824 - accuracy: 0.3233 - val_loss: 0.5867 - val_accuracy: 0.2867
# Epoch 17/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5823 - accuracy: 0.3225 - val_loss: 0.5866 - val_accuracy: 0.3443
# Epoch 18/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5826 - accuracy: 0.3232 - val_loss: 0.5866 - val_accuracy: 0.2835
# Epoch 19/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5822 - accuracy: 0.3216 - val_loss: 0.5865 - val_accuracy: 0.3003
# Epoch 20/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5822 - accuracy: 0.3211 - val_loss: 0.5862 - val_accuracy: 0.2511
# Epoch 21/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5820 - accuracy: 0.3183 - val_loss: 0.5861 - val_accuracy: 0.3004
# Epoch 22/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5820 - accuracy: 0.3239 - val_loss: 0.5862 - val_accuracy: 0.2969
# Epoch 23/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5825 - accuracy: 0.3062 - val_loss: 0.5890 - val_accuracy: 0.2983
# Epoch 24/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5840 - accuracy: 0.2640 - val_loss: 0.5866 - val_accuracy: 0.5524
# Epoch 25/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5822 - accuracy: 0.3076 - val_loss: 0.5861 - val_accuracy: 0.2573
# Epoch 26/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5819 - accuracy: 0.2797 - val_loss: 0.5860 - val_accuracy: 0.3664
# Epoch 27/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5818 - accuracy: 0.3029 - val_loss: 0.5862 - val_accuracy: 0.2180
# Epoch 28/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5817 - accuracy: 0.2981 - val_loss: 0.5859 - val_accuracy: 0.2518
# Epoch 29/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5816 - accuracy: 0.2756 - val_loss: 0.5858 - val_accuracy: 0.3150
# Epoch 30/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5817 - accuracy: 0.2820 - val_loss: 0.5868 - val_accuracy: 0.3256
# Epoch 31/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5821 - accuracy: 0.2343 - val_loss: 0.5859 - val_accuracy: 0.3453
# Epoch 32/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5816 - accuracy: 0.3011 - val_loss: 0.5858 - val_accuracy: 0.2135
# Epoch 33/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5816 - accuracy: 0.2779 - val_loss: 0.5861 - val_accuracy: 0.1890
# Epoch 34/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5819 - accuracy: 0.2756 - val_loss: 0.5858 - val_accuracy: 0.2837
# Epoch 35/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5816 - accuracy: 0.2772 - val_loss: 0.5857 - val_accuracy: 0.1910
# Epoch 36/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5814 - accuracy: 0.2651 - val_loss: 0.5856 - val_accuracy: 0.3098
# Epoch 37/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5814 - accuracy: 0.2777 - val_loss: 0.5856 - val_accuracy: 0.3045
# Epoch 38/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5814 - accuracy: 0.2665 - val_loss: 0.5855 - val_accuracy: 0.2384
# Epoch 39/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5813 - accuracy: 0.2624 - val_loss: 0.5854 - val_accuracy: 0.2268
# Epoch 40/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5813 - accuracy: 0.2651 - val_loss: 0.5859 - val_accuracy: 0.3186
# Epoch 41/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5814 - accuracy: 0.2723 - val_loss: 0.5855 - val_accuracy: 0.2524
# Epoch 42/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5811 - accuracy: 0.2610 - val_loss: 0.5853 - val_accuracy: 0.2733
# Epoch 43/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5811 - accuracy: 0.2547 - val_loss: 0.5852 - val_accuracy: 0.2660
# Epoch 44/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5811 - accuracy: 0.2581 - val_loss: 0.5853 - val_accuracy: 0.2270
# Epoch 45/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5812 - accuracy: 0.2591 - val_loss: 0.5850 - val_accuracy: 0.2602
# Epoch 46/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5811 - accuracy: 0.2439 - val_loss: 0.5851 - val_accuracy: 0.2409
# Epoch 47/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5811 - accuracy: 0.2548 - val_loss: 0.5851 - val_accuracy: 0.2590
# Epoch 48/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5809 - accuracy: 0.2428 - val_loss: 0.5850 - val_accuracy: 0.1995
# Epoch 49/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5809 - accuracy: 0.2505 - val_loss: 0.5849 - val_accuracy: 0.2569
# Epoch 50/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5809 - accuracy: 0.2395 - val_loss: 0.5848 - val_accuracy: 0.2446
# Epoch 51/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5808 - accuracy: 0.2433 - val_loss: 0.5848 - val_accuracy: 0.2518
# Epoch 52/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5808 - accuracy: 0.2520 - val_loss: 0.5851 - val_accuracy: 0.2012
# Epoch 53/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5808 - accuracy: 0.2408 - val_loss: 0.5848 - val_accuracy: 0.3337
# Epoch 54/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5808 - accuracy: 0.2436 - val_loss: 0.5850 - val_accuracy: 0.3025
# Epoch 55/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5810 - accuracy: 0.2340 - val_loss: 0.5847 - val_accuracy: 0.3669
# Epoch 56/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5807 - accuracy: 0.2541 - val_loss: 0.5846 - val_accuracy: 0.2229
# Epoch 57/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5808 - accuracy: 0.2516 - val_loss: 0.5857 - val_accuracy: 0.3108
# Epoch 58/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5810 - accuracy: 0.2581 - val_loss: 0.5845 - val_accuracy: 0.2074
# Epoch 59/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5808 - accuracy: 0.2492 - val_loss: 0.5848 - val_accuracy: 0.2562
# Epoch 60/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5805 - accuracy: 0.2400 - val_loss: 0.5844 - val_accuracy: 0.3086
# Epoch 61/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5805 - accuracy: 0.2655 - val_loss: 0.5844 - val_accuracy: 0.2951
# Epoch 62/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5806 - accuracy: 0.2479 - val_loss: 0.5849 - val_accuracy: 0.2822
# Epoch 63/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5804 - accuracy: 0.2475 - val_loss: 0.5854 - val_accuracy: 0.3148
# Epoch 64/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5815 - accuracy: 0.2978 - val_loss: 0.5849 - val_accuracy: 0.2636
# Epoch 65/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5808 - accuracy: 0.2413 - val_loss: 0.5844 - val_accuracy: 0.2331
# Epoch 66/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5804 - accuracy: 0.2541 - val_loss: 0.5842 - val_accuracy: 0.3076
# Epoch 67/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5806 - accuracy: 0.2615 - val_loss: 0.5846 - val_accuracy: 0.2724
# Epoch 68/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5806 - accuracy: 0.2570 - val_loss: 0.5845 - val_accuracy: 0.2478
# Epoch 69/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5803 - accuracy: 0.2696 - val_loss: 0.5842 - val_accuracy: 0.2522
# Epoch 70/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5803 - accuracy: 0.2442 - val_loss: 0.5843 - val_accuracy: 0.2574
# Epoch 71/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5802 - accuracy: 0.2609 - val_loss: 0.5842 - val_accuracy: 0.2324
# Epoch 72/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5804 - accuracy: 0.2732 - val_loss: 0.5842 - val_accuracy: 0.2441
# Epoch 73/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5804 - accuracy: 0.2563 - val_loss: 0.5842 - val_accuracy: 0.3376
# Epoch 74/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5806 - accuracy: 0.2443 - val_loss: 0.5847 - val_accuracy: 0.4389
# Epoch 75/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5809 - accuracy: 0.2630 - val_loss: 0.5843 - val_accuracy: 0.3233
# Epoch 76/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5803 - accuracy: 0.2702 - val_loss: 0.5845 - val_accuracy: 0.3646
# Epoch 77/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5802 - accuracy: 0.2719 - val_loss: 0.5842 - val_accuracy: 0.1934
# Epoch 78/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5802 - accuracy: 0.2858 - val_loss: 0.5840 - val_accuracy: 0.2342
# Epoch 79/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5803 - accuracy: 0.2691 - val_loss: 0.5840 - val_accuracy: 0.3341
# Epoch 80/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5802 - accuracy: 0.2567 - val_loss: 0.5840 - val_accuracy: 0.3666
# Epoch 81/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5801 - accuracy: 0.2808 - val_loss: 0.5842 - val_accuracy: 0.2708
# Epoch 82/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5802 - accuracy: 0.2717 - val_loss: 0.5839 - val_accuracy: 0.3087
# Epoch 83/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5802 - accuracy: 0.2805 - val_loss: 0.5839 - val_accuracy: 0.2366
# Epoch 84/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5801 - accuracy: 0.2741 - val_loss: 0.5839 - val_accuracy: 0.2708
# Epoch 85/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5801 - accuracy: 0.2804 - val_loss: 0.5838 - val_accuracy: 0.2719
# Epoch 86/100
# 32/32 [==============================] - 40s 1s/step - loss: 0.5800 - accuracy: 0.2788 - val_loss: 0.5841 - val_accuracy: 0.3468
# Epoch 87/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5800 - accuracy: 0.2771 - val_loss: 0.5838 - val_accuracy: 0.3449
# Epoch 88/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5801 - accuracy: 0.2833 - val_loss: 0.5853 - val_accuracy: 0.3840
# Epoch 89/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5805 - accuracy: 0.2765 - val_loss: 0.5840 - val_accuracy: 0.3298
# Epoch 90/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5800 - accuracy: 0.2865 - val_loss: 0.5838 - val_accuracy: 0.2543
# Epoch 91/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5799 - accuracy: 0.2847 - val_loss: 0.5837 - val_accuracy: 0.2586
# Epoch 92/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5801 - accuracy: 0.2752 - val_loss: 0.5840 - val_accuracy: 0.2866
# Epoch 93/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5799 - accuracy: 0.2855 - val_loss: 0.5838 - val_accuracy: 0.2928
# Epoch 94/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5802 - accuracy: 0.2730 - val_loss: 0.5840 - val_accuracy: 0.2411
# Epoch 95/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5799 - accuracy: 0.2928 - val_loss: 0.5838 - val_accuracy: 0.2012
# Epoch 96/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5800 - accuracy: 0.2782 - val_loss: 0.5840 - val_accuracy: 0.2486
# Epoch 97/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5803 - accuracy: 0.2741 - val_loss: 0.5840 - val_accuracy: 0.3756
# Epoch 98/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5799 - accuracy: 0.2854 - val_loss: 0.5836 - val_accuracy: 0.2616
# Epoch 99/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5799 - accuracy: 0.2824 - val_loss: 0.5839 - val_accuracy: 0.2852
# Epoch 100/100
# 32/32 [==============================] - 38s 1s/step - loss: 0.5800 - accuracy: 0.2652 - val_loss: 0.5838 - val_accuracy: 0.2671

# %%
autoencoder7 = Model(input, out_7)
opt = keras.optimizers.Adam(learning_rate=lr_schedule)
autoencoder7.compile(optimizer=opt, loss="binary_crossentropy", metrics = ['accuracy'])
autoencoder7.summary()
history7 = autoencoder7.fit(x=train_images_noisy,y=train_images,epochs=100,batch_size=16,validation_data=(val_images_noisy, val_images), callbacks = [early_stopping])
filename = '7_layer.sav'
pickle.dump(autoencoder7, open(filename, 'wb'))

# %% [markdown]
# #FITTING DATA

# %% [markdown]
# # Sharpen Image

# %% [markdown]
# #CREATING TEST DATASET

# %%
# test_image = tf.keras.preprocessing.image.load_img("/content/drive/MyDrive/datas/train400/007.png")
# test_image = test_image.resize((300,300))
# input_arr = tf.keras.preprocessing.image.img_to_array(test_image)
# print(type(input_arr))
# test_image = np.divide(input_arr, 255.0)

plt.imshow(images[7])

# %%
# test_image_noisy = noisy(test_image)
plt.imshow(noisy_images[7])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #PREDICTING MODEL

# %% [markdown]
# Output for 1 Layer

# %%
reco = autoencoder1.predict(noisy_images[7][None])[0]
plt.imshow(reco)

# %% [markdown]
# output for 3 layers

# %%
reco = autoencoder3.predict(test_image_noisy[None])[0]
plt.imshow(reco)

# %% [markdown]
# output 5 layers

# %%
reco = autoencoder5.predict(test_image_noisy[None])[0]
plt.imshow(reco)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b7337c5829c2> in <module>()
# ----> 1 reco = autoencoder5.predict(test_image_noisy[None])[0]
#       2 plt.imshow(reco)
#
# NameError: name 'autoencoder5' is not defined

# %% [markdown]
# output 7 layers

# %%
reco = autoencoder7.predict(test_image_noisy[None])[0]
plt.imshow(reco)

# %% [markdown]
# #PLOTTING GRAPH

# %%
def plotting_graph(history,parameter):
  Y = []
  Z = []
  if parameter is "Loss":
    Y = np.array(history.history['loss'])
    Z = np.array(history.history['val_loss'])
  else:
    Y = np.array(history.history['accuracy'])
    Z = np.array(history.history['val_accuracy'])

  plt.plot(Y, color='r', label='training '+parameter)
  plt.plot(Z, color='g', label='validation '+parameter)
  plt.xlabel("Epochs")
  plt.ylabel(parameter)
  plt.title("{} vs Epoch".format(parameter))

  plt.legend()
  plt.show()

# %%
plotting_graph(history,"Loss")
plotting_graph(history,"Accuracy")
